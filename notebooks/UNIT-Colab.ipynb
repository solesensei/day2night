# %% [markdown]
# # UNIT Project at Colab
# [on GitHub](https://github.com/mingyuliutw/UNIT)

# %% [markdown]
# ## Workspace Setup
# Bash commands setting up the current session for Juputer Notebook

# %% [markdown]
# ### Google Drive Folder Mounting
# Following code mounts your google.drive to container. Choose **one** of next **two** methods.

# %%
#@markdown #### Mounting (built-in)
print('Mounting...')
import os
from google.colab import drive
os.chdir('/content/')
drive.mount('/drive/', force_remount=True)
if os.path.exists('/content/drive'):
    os.unlink('/content/drive')
os.symlink('/drive/My Drive', '/content/drive')
# !ls '/content/drive/'
print('Mounted!')
# Out:
# Mounting...
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /drive/
#  Colab		    Graduation				     README.md
# 'Colab Notebooks'  'My backup - 02 27 2019 - 08:36.gsheet'   UNIT
#  datasets	    ParseData
# Mounted!

# %%
from shutil import copy, move
import zipfile
import os
root = "/content/drive/datasets/bdd100k"
# !ls /content/drive/datasets
rdst = root + "_copy"
zipath = "/content/drive/datasets/bdd100k_images.zip"
zip_ref = zipfile.ZipFile(zipath, 'r')
zip_ref.extractall(rdst)
zip_ref.close()

if not os.path.exists(rdst):
    os.mkdir(rdst)
    
for r,dirs,files in os.walk(root):
    dst = rdst + r[len(root):]
    print(f'{r} -> {dst}')
    if not os.path.exists(dst):
        os.mkdir(dst)
    for i, f in enumerate(files):
        if i % 1000 == 0:
            print(f'{i * 100 // len(files)}% copied')
        src = r + "/" + f
        if not os.path.exists(dst + "/" + f):
            move(src,dst)
    print('100% copied')
# Out:
#  bdd100k        bdd100k_images.zip	      nexet
#  bdd100k_copy  'Copy of bdd100k_images.zip'

# %%
#@markdown #### Mounting With Fuse Driver (google-drive-ocamlfuse)
print('Mounting Google.Drive with google-drive-ocamlfuse...')
% cd /content/
print('Installing required software')
! apt-get install -y -qq software-properties-common module-init-tools 2>&1 > /dev/null
print('Add apt-repository with Google.Drive Fuse')
! add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
print('Updating packages...')
! apt-get update -y -qq
print('Installing google-drive-ocamlfuse fuse...')
! apt-get install -y -qq google-drive-ocamlfuse fuse
print('Authenticate Fuse in Google.Drive...')
from google.colab import auth
from oauth2client.client import GoogleCredentials
import getpass
auth.authenticate_user()
creds = GoogleCredentials.get_application_default()
! google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass('Enter auth code here: ')
! echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
print('Authenticated!')
print('Creating mount directory')
! mkdir /drive2
print('Mounting...')
! google-drive-ocamlfuse /drive2
if os.path.exists('/content/drive'):
    os.unlink('/content/drive')
os.symlink('/drive2', '/content/drive')
# !ls '/content/drive/'
print('Mounted!')

# %% [markdown]
# ### SSH Tunnel

# %%
#@markdown ## Connect to Colab session
#@markdown Using ngrok
port = 4040 #@param {type:"integer"}
only_show_credetionals = True #@param {type:"boolean"}
# %cd /content/
if not only_show_credetionals:
    print('Generate root password')
    import secrets, string
    password = ''.join(secrets.choice(string.ascii_letters + string.digits) for i in range(20))
    ! echo "Password: $password" > /content/save_pswd
    print('Download ngrok')
    ! wget -q -c -nc https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
    ! unzip -qq -n ngrok-stable-linux-amd64.zip
    print('Setup sshd')
    ! apt-get install -qq -o=Dpkg::Use-Pty=0 openssh-server pwgen > /dev/null
    print('Set root password')
    ! echo root:$password | chpasswd
    ! mkdir -p /var/run/sshd
    ! echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
    ! echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config
    ! echo "LD_LIBRARY_PATH=/usr/lib64-nvidia" >> /root/.bashrc
    ! echo "export LD_LIBRARY_PATH" >> /root/.bashrc

    print('Run sshd')
    get_ipython().system_raw('/usr/sbin/sshd -D &')

    print("Copy authtoken from https://dashboard.ngrok.com/auth")
    import getpass
    authtoken = getpass.getpass()

    print('Create tunnel')
    get_ipython().system_raw('./ngrok authtoken $authtoken && ./ngrok tcp 22 &')

print('---------')
import sys, json, os
try:
    s = !curl -s http://localhost:$port/api/tunnels
    addr = str(json.loads(s[0])['tunnels'][0]['public_url'])
    print('Use:', end=' ')
    print('ssh root@' + addr[6:addr.find(':', 6)] + ' -p ' + addr[addr.find(':', 6)+1:])
    if os.path.exists('/content/save_pswd'):
        ! cat /content/save_pswd
except:
    print('Tunnel was closed!')

# %% [markdown]
# # Project

# %% [markdown]
# ### Install Dependencies
# Session startup installation

# %%
#@markdown ## Dependencies
Project = 'google.drive' #@param ['google.drive', 'clone github'] 
copy_pre_trained_model = False #@param {type:"boolean"}

if Project == 'clone github':
    print('Cloning GitHub project...')
    # !git clone https://github.com/SoleSensei/UNIT.git
    if copy_pre_trained_model:
        print('Copying PT model gta2city...')
        # !mkdir /content/UNIT/models
        # !mkdir /content/UNIT/outputs
        # !cp -r /content/drive/UNIT/models/ /content/UNIT/
        # !cp -r /content/drive/UNIT/output/ /content/UNIT/

# !apt-get update 2>&1 > /dev/null
print('Installing system packages...')
# !apt-get install -y -qq axel imagemagick 2>&1 > /dev/null
print('Installing project dependencies...')
# !pip3 install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl 2>&1 > /dev/null
# !pip3 install torch torchvision 2>&1 > /dev/null
# !pip3 install tensorboard tensorboardX 2>&1 > /dev/null
print('Complete!')
# Out:
# Installing system packages...
# Installing project dependencies...
# Complete!

# %% [markdown]
# ## Train

# %% [markdown]
# ### Day-2-Night Translation

# %%
#@title Shift Domains (nexet dataset)
#@markdown Script parsing dataset folder to several domains by states from csv file

import pandas as pd
import os, sys
from shutil import copy, move

os.chdir('/content/drive/datasets/nexet')
# ------------------------ Variables ------------------------ 
datapath = '/content/drive/datasets/nexet/nexet_2017_1/' # path to dataset directory
csvfile = '/content/drive/datasets/nexet/train.csv' # path to csv file
col_name = 'image_filename' # column name with dataset's filenames
col_state = 'lighting' # column name with dataset's states 
domains = {
            'trainA' : 'Day',
            'trainB' : 'Night',
            'testA' : 'Day',
            'testB' : 'Night'
          }  # making domain directories {Domain_Name : States}
mode = 'move' # 'move' | 'copy' all files from dataset folder to domains
domains2data = False # set True to shift all files back to datapath
# -----------------------------------------------------------
 
# ------------------------ Dynamic Variables ------------------------ 
mode = "move" #@param ["move", "copy", "none"]
domains2data = False #@param {type:"boolean"}
show_errors = 5 #@param {type:"slider", min:0, max:100, step:1}
show_log = 10 #@param {type:"slider", min:0, max:100, step:1}
train_test_ratio = 90 #@param {type:"slider", min:5, max:95, step:5}
# -----------------------------------------------------------


class DomainShifter(object):
    """
        Class creating dataset's domains from csv 
    """

    def get_states(self, column):
        """ Getting states by csv file column """

        print(f'Searching states in {column}...')
        states = set()
        for state in self.csv[column]:
            states.add(state) 
        print("States:", *states)
        return states

    def __init__(self, data, file, domains, col_name, col_state, sep=','):
        
        # Check datasets paths
        if not os.path.exists(data):
            raise FileNotFoundError(f"No dataset '{os.path.abspath(data)}' folder found!")
        if not os.path.exists(file):
            raise FileNotFoundError(f"No csv file '{os.path.abspath(file)}' found!")

        def check_cols(*cols):
            """ Check if columns exist in csv """
            try:
                for col in cols:
                    self.csv[col]
            except:
                raise Exception(f'Column name "{col}" is not found in {self.file}!')
        
        # Initialize class local variables
        self.dataset = data # dataset path
        self.file = file # csv file path
        self.domains = domains # domains to create
        self.csv = pd.read_csv(file, sep=sep, encoding='utf8') # read csv with pandas
        check_cols(col_name, col_state) # check on column names exists
        self.states = self.get_states(col_state) # get all states from csv
    
    def back_data(self, mode='move'):
        """ Backing up data from domain folders to dataset folder """
        if mode == 'copy':
            shift = copy
        elif mode == 'move':
            shift = move
        else:
            raise Exception(f'Shift Domains: no {mode} found!')

        print('Backup shifting starts...')
        print(f'Mode: {shift.__name__}')  

        with open('log.txt', 'a', encoding="utf-8") as log, open('err.txt', 'a', encoding="utf-8") as err:
            print('-------- back data ----------', file=log)
            print('-------- back data ----------', file=err)
            for root, sdir, _ in os.walk(self.dataset):
                for folder in sdir:
                    if folder in self.domains.keys():
                        print(f'Start parsing {folder}')
                        print(f'Start parsing {folder}', file=log)
                        for r, _, files in os.walk(os.path.join(root, folder)):
                            nfile = len(files)
                            print('Files:', nfile)
                            for i, name in enumerate(files):
                                if i % (nfile // 30 + 1) == 0:
                                    print(i, 'files shifted')
                                src = os.path.join(r, name)
                                dst = os.path.join(root, name)
                                if mode == 'move' or not os.path.exists(dst):
                                    shift(src, dst)
                        print(f'Parsed: {folder}') 
                        print(f'Parsed: {folder}', file=log)
                    else:
                        print(f'Not domain folder {folder} found')
                        print(f'Not domain folder {folder} found', file=log)


    def shift_domains(self, mode='move'):
        """ Creating domain folders and parsing dataset folder by csv """
        if mode == 'copy':
            shift = copy
        elif mode == 'move':
            shift = move
        else:
            raise Exception(f'Shift Domains: no {mode} found!')
        print('Shifting domains starts...')
        print(f'Mode: {shift.__name__}')
        # Caclculate splits
        domain_split = {}
        for state in self.states:
            domain_split[state] = sum(state in v for v in self.domains.values())
        
        # Creating directories
        print('Creating directories...')
        base = self.dataset
        for ndir in self.domains.keys():
            path = os.path.join(base, ndir)
            if not os.path.isdir(path):
                os.mkdir(path)
                print(f'{path} created!')
        print('Created!')
        
#         k = 0 # TODO: fix dict for count
        k_state = {'Day' : 0, 'Night' : 0}
        with open('log.txt', 'a', encoding="utf-8") as log, open('err.txt', 'a', encoding="utf-8") as err:
            print('-------- shift domains ----------', file=err)
            print('-------- shift domains ----------', file=log)
            for i, row in self.csv.iterrows():
                if i % 1000 == 0:
                    print(i, 'files processed')
                name = str(row[col_name])
                state = str(row[col_state])
                src = os.path.join(base, name)
                is_shifted = False
                
                if state == 'Twilight':
                    continue
#                 k += 1
                k_state[state] += 1
                if k_state[state] % 100 < train_test_ratio: #TODO: add domain split
                    domain_type = 'train'
                else:
                    domain_type = 'test'

                for item in self.domains.items():
                    if state in item[1] and item[0][:-1] == domain_type:
                        dst = os.path.join(base, item[0])
                        dstname = os.path.join(dst, name)
                        if os.path.exists(src) and (mode == 'move' or not os.path.exists(dstname)):
                            shift(src, dst)
                            print(f'{shift.__name__}: {src} → {dst}', file=log)
                            is_shifted = True
                        elif os.path.exists(dstname):
                            is_shifted = True
                        break
                if not is_shifted:
                    print(f'{row[col_name]} file not shifted', file=err)
            for root, sdir, _ in os.walk(self.dataset):
                for folder in sdir:
                    if folder in self.domains.keys():
                        for _, _, files in os.walk(os.path.join(root, folder)):
                            nfile = len(files)
                            print(f'Files in domain {folder}: {nfile}')
                            print(f'Files in domain {folder}: {nfile}', file=log)
        print('Shifiting completed!')

# Main
ds = DomainShifter(datapath, csvfile, domains, col_name, col_state)
if not domains2data:
    ds.shift_domains(mode)
else:
    ds.back_data(mode)


if show_errors:
    print('Error log:')
    # !tail -n $show_errors err.txt
if show_log:
    print('Log:')
    # !tail -n $show_log log.txt
print('Completed!')
# Out:
# Searching states in lighting...
# States: Night Day Twilight
# Backup shifting starts...
# Mode: move
# Error log:
# frame_67012509-f3bd-4175-a9d2-565a7b6bb3c7_00001-1280_720.jpg file not shifted
# frame_bd043377-6fb8-407a-95e5-7deb1fbab13a_00004-1280_720.jpg file not shifted
# frame_4da1583b-58d0-4893-8149-54541191031d_00000-1280_720.jpg file not shifted
# -------- back data ----------
# -------- back data ----------
# Log:
# -------- back data ----------
# Start parsing trainB
# Parsed: trainB
# Start parsing trainA
# Parsed: trainA
# Start parsing testB
# Parsed: testB
# Start parsing testA
# Parsed: testA
# -------- back data ----------
# Completed!

# %%
#@title Check on currupted images
#@markdown Script checking and moving currupted images to special directory
import os, sys
from shutil import move
from PIL import Image

datapath = '/content/drive/datasets/nexet/nexet_2017_1/' # path to dataset directory
curr_dir = '/content/drive/datasets/nexet/currupted'

os.chdir('/content/drive/datasets/nexet')

if not os.path.exists(curr_dir):
    os.mkdir(curr_dir)

with open('log.txt', 'a') as log:
    print('-------- check currupted ----------', file=log)
    curr_count = {}
    for root, _, files in os.walk(datapath):
        print(f'Checking {root} : ', file=log)
        print(f'Checking {root} : ')
        curr_count[root] = 0
        nfile = len(files)
        for i, file in enumerate(files):
            if i % 100 == 0:
                print(nfile - i, 'left to process')
            try:
                src = os.path.join(root, file)
                with open(src, 'rb') as byte_image:
                    with Image.open(byte_image) as img:
                        img.verify()
            except (IOError, SyntaxError) as e:
                curr_count[root] += 1
                move(src, curr_dir)
                print(f'currupted move: {src} → {curr_dir}', file=log)
        print('All Processed!')
        print(curr_count[root], 'errors', file=log)
        print(curr_count[root], 'errors')
    num_errors = sum(v for v in curr_count.values())
    print(f'Number of currupted files: {num_errors}', file=log)
    
show_log = 7 #@param {type:"slider", min:0, max:100, step:1}
if show_log:
    print('Log:')
    # !tail -n $show_log log.txt
print('Completed!')

# %%
#@title ## Training Day 2 Night
Resume_from_last_checkpoint = True #@param {type:"boolean"}
Checkpoint_every_iteration = 1000 #@param {type:"slider", min:100, max:5000, step:100}
# TODO: add changing yaml file
 
if Resume_from_last_checkpoint:
    rsm = '--resume'
else:
    rsm = ''

import os
if not os.path.isdir('/content/drive'):
    print('=====================================================================')
    print('Session ended! Please remount google.drive and reinstall dependences!')
    print('=====================================================================')
else:
    os.chdir('/content/drive/UNIT')

    print('=====================================================================')
    print('Training a model Day to Night image translation')
    print('=====================================================================')
    # !python train.py --config configs/unit_day2night4.yaml --trainer UNIT $rsm
    print('=====================================================================')
    print('Fully Trained!')
    print('=====================================================================')
# Out:
# =====================================================================
# Training a model Day to Night image translation
# =====================================================================
# Image Size: 256px
# Processed 0 images
# Processed 1000 images
# Processed 2000 images
# Processed 3000 images
# Processed 4000 images
# Processed 5000 images
# Processed 6000 images
# Processed 7000 images
# Processed 8000 images
# Processed 9000 images
# Processed 10000 images
# Processed 11000 images
# Processed 12000 images
# Processed 13000 images
# Processed 14000 images
# Processed 15000 images
# Processed 16000 images
# Processed 17000 images
# Processed 18000 images
# 18648
# Processed 0 images
# Processed 1000 images
# Processed 2000 images
# 2490
# Processed 0 images
# Processed 1000 images
# Processed 2000 images
# Processed 3000 images
# Processed 4000 images
# Processed 5000 images
# Processed 6000 images
# Processed 7000 images
# Processed 8000 images
# Processed 9000 images
# Processed 10000 images
# Processed 11000 images
# Processed 12000 images
# Processed 13000 images
# Processed 14000 images
# Processed 15000 images
# Processed 16000 images
# Processed 17000 images
# Processed 18000 images
# Processed 19000 images
# Processed 20000 images
# 20903
# Processed 0 images
# Processed 1000 images
# 1585
# Resume from iteration 12500
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# Elapsed time in update: 6.373711
# Elapsed time in update: 2.237722
# Elapsed time in update: 2.222320
# Elapsed time in update: 2.258449
# Elapsed time in update: 2.209343
# Elapsed time in update: 2.201437
# Elapsed time in update: 2.236998
# Elapsed time in update: 2.217341
# Elapsed time in update: 2.200219
# Elapsed time in update: 2.246067
# Iteration: 00012510/01000000
# Elapsed time in update: 2.222211
# Elapsed time in update: 2.191404
# Elapsed time in update: 2.205090
# Elapsed time in update: 2.202867
# Elapsed time in update: 2.200162
# Elapsed time in update: 2.189696
# Elapsed time in update: 2.204017
# Elapsed time in update: 2.204304
# Elapsed time in update: 2.195001
# Elapsed time in update: 2.199412
# Iteration: 00012520/01000000
# Elapsed time in update: 2.191643
# Elapsed time in update: 2.212692
# Elapsed time in update: 2.204123
# Elapsed time in update: 2.213605
# Elapsed time in update: 2.192904
# Elapsed time in update: 2.189775
# Elapsed time in update: 2.179374
# Elapsed time in update: 2.199624
# Elapsed time in update: 2.206355
# Elapsed time in update: 2.187730
# Iteration: 00012530/01000000
# Elapsed time in update: 2.200313
# Elapsed time in update: 2.208169
# Elapsed time in update: 2.202540
# Elapsed time in update: 2.194614
# Elapsed time in update: 2.190559
# Elapsed time in update: 2.227267
# Elapsed time in update: 2.181805
# Elapsed time in update: 2.200844
# Elapsed time in update: 2.189310
# Elapsed time in update: 2.173727
# Iteration: 00012540/01000000
# Elapsed time in update: 2.177808
# Elapsed time in update: 2.200702
# Elapsed time in update: 2.196676
# Elapsed time in update: 2.180557
# Elapsed time in update: 2.182536
# Elapsed time in update: 2.209864
# Elapsed time in update: 2.222847
# Elapsed time in update: 2.192749
# Elapsed time in update: 2.223087
# Elapsed time in update: 2.194758
# Iteration: 00012550/01000000
# Elapsed time in update: 2.181312
# Elapsed time in update: 2.206366
# Elapsed time in update: 2.190400
# Elapsed time in update: 2.175615
# Elapsed time in update: 2.194957
# Elapsed time in update: 2.190694
# Elapsed time in update: 2.207732
# Elapsed time in update: 2.193873
# Elapsed time in update: 2.191534
# Elapsed time in update: 2.202262
# Iteration: 00012560/01000000
# Elapsed time in update: 2.214457
# Elapsed time in update: 2.217239
# Elapsed time in update: 2.207808
# Elapsed time in update: 2.185016
# Elapsed time in update: 2.200338
# Elapsed time in update: 2.201358
# Elapsed time in update: 2.191712
# Elapsed time in update: 2.199852
# Elapsed time in update: 2.192531
# Elapsed time in update: 2.192929
# Iteration: 00012570/01000000
# Elapsed time in update: 2.175017
# Elapsed time in update: 2.198962
# Elapsed time in update: 2.179724
# Elapsed time in update: 2.196631
# Elapsed time in update: 2.184616
# Elapsed time in update: 2.199277
# Elapsed time in update: 2.235687
# Elapsed time in update: 2.231408
# Elapsed time in update: 2.192124
# Elapsed time in update: 2.186829
# Iteration: 00012580/01000000
# Elapsed time in update: 2.186691
# Elapsed time in update: 2.197263
# Elapsed time in update: 2.196695
# Elapsed time in update: 2.179440
# Elapsed time in update: 2.189111
# Elapsed time in update: 2.203097
# Elapsed time in update: 2.175458
# Elapsed time in update: 2.201074
# Elapsed time in update: 2.192766
# Elapsed time in update: 2.194949
# Iteration: 00012590/01000000
# Elapsed time in update: 2.216651
# Elapsed time in update: 2.209226
# Elapsed time in update: 2.190461
# Elapsed time in update: 2.177420
# Elapsed time in update: 2.181758
# Elapsed time in update: 2.198157
# Elapsed time in update: 2.191585
# Elapsed time in update: 2.194545
# Elapsed time in update: 2.186778
# Elapsed time in update: 2.192513
# Iteration: 00012600/01000000
# Elapsed time in update: 2.187444
# Elapsed time in update: 2.181212
# Elapsed time in update: 2.187942
# Elapsed time in update: 2.200213
# Elapsed time in update: 2.212117
# Elapsed time in update: 2.196150
# Elapsed time in update: 2.191773
# Elapsed time in update: 2.190068
# Elapsed time in update: 2.196617
# Elapsed time in update: 2.204997
# Iteration: 00012610/01000000
# Elapsed time in update: 2.187372
# Elapsed time in update: 2.221624
# Elapsed time in update: 2.223759
# Elapsed time in update: 2.194058
# Elapsed time in update: 2.192295
# Elapsed time in update: 2.198300
# Elapsed time in update: 2.207894
# Elapsed time in update: 2.209830
# Elapsed time in update: 2.182025
# Elapsed time in update: 2.210566
# Iteration: 00012620/01000000
# Elapsed time in update: 2.201075
# Elapsed time in update: 2.218742
# Elapsed time in update: 2.191669
# Elapsed time in update: 2.181325
# Elapsed time in update: 2.179887
# Elapsed time in update: 2.201042
# Elapsed time in update: 2.185749
# Elapsed time in update: 2.208882
# Elapsed time in update: 2.201868
# Elapsed time in update: 2.218795
# Iteration: 00012630/01000000
# Elapsed time in update: 2.198939
# Elapsed time in update: 2.198348
# Elapsed time in update: 2.192104
# Elapsed time in update: 2.187720
# Elapsed time in update: 2.203383
# Elapsed time in update: 2.197022
# Elapsed time in update: 2.201855
# Elapsed time in update: 2.225892
# Elapsed time in update: 2.205215
# Elapsed time in update: 2.183052
# Iteration: 00012640/01000000
# Elapsed time in update: 2.197048
# Elapsed time in update: 2.206846
# Elapsed time in update: 2.218704
# Elapsed time in update: 2.188508
# Elapsed time in update: 2.214867
# Elapsed time in update: 2.214075
# Elapsed time in update: 2.205255
# Elapsed time in update: 2.194817
# Elapsed time in update: 2.183676
# Elapsed time in update: 2.177978
# Iteration: 00012650/01000000
# Elapsed time in update: 2.188526
# Elapsed time in update: 2.204258
# Elapsed time in update: 2.182494
# Elapsed time in update: 2.218611
# Elapsed time in update: 2.183622
# Elapsed time in update: 2.200682
# Elapsed time in update: 2.200629
# Elapsed time in update: 2.197986
# Elapsed time in update: 2.192537
# Elapsed time in update: 2.183929
# Iteration: 00012660/01000000
# Elapsed time in update: 2.217184
# Elapsed time in update: 2.195316
# Elapsed time in update: 2.185077
# Elapsed time in update: 2.179025
# Elapsed time in update: 2.219798
# Elapsed time in update: 2.227482
# Elapsed time in update: 2.233630
# Elapsed time in update: 2.197092
# Elapsed time in update: 2.212215
# Elapsed time in update: 2.183021
# Iteration: 00012670/01000000
# Elapsed time in update: 2.202072
# Elapsed time in update: 2.198762
# Elapsed time in update: 2.198220
# Elapsed time in update: 2.193011
# Elapsed time in update: 2.217097
# Elapsed time in update: 2.185457
# Elapsed time in update: 2.225670
# Elapsed time in update: 2.189916
# Elapsed time in update: 2.205128
# Elapsed time in update: 2.210028
# Iteration: 00012680/01000000
# Elapsed time in update: 2.173726
# Elapsed time in update: 2.185700
# Elapsed time in update: 2.199396
# Elapsed time in update: 2.232628
# Elapsed time in update: 2.189896
# Elapsed time in update: 2.207125
# Elapsed time in update: 2.209529
# Elapsed time in update: 2.189171
# Elapsed time in update: 2.206396
# Elapsed time in update: 2.189699
# Iteration: 00012690/01000000
# Elapsed time in update: 2.173488
# Elapsed time in update: 2.197738
# Elapsed time in update: 2.197017
# Elapsed time in update: 2.181919
# Elapsed time in update: 2.191848
# Elapsed time in update: 2.171225
# Elapsed time in update: 2.182911
# Elapsed time in update: 2.209158
# Elapsed time in update: 2.181227
# Elapsed time in update: 2.182928
# Iteration: 00012700/01000000
# Elapsed time in update: 2.202656
# Elapsed time in update: 2.185517
# Elapsed time in update: 2.206033
# Elapsed time in update: 2.188607
# Elapsed time in update: 2.193440
# Elapsed time in update: 2.231257
# Elapsed time in update: 2.204241
# Elapsed time in update: 2.191221
# Elapsed time in update: 2.184580
# Elapsed time in update: 2.176956
# Iteration: 00012710/01000000
# Elapsed time in update: 2.168867
# Elapsed time in update: 2.191841
# Elapsed time in update: 2.186497
# Elapsed time in update: 2.198441
# Elapsed time in update: 2.190810
# Elapsed time in update: 2.190224
# Elapsed time in update: 2.183142
# Elapsed time in update: 2.166308
# Elapsed time in update: 2.191978
# Elapsed time in update: 2.204430
# Iteration: 00012720/01000000
# Elapsed time in update: 2.219289
# Elapsed time in update: 2.192958
# Elapsed time in update: 2.185766
# Elapsed time in update: 2.204111
# Elapsed time in update: 2.209235
# Elapsed time in update: 2.193569
# Elapsed time in update: 2.174521
# Elapsed time in update: 2.170333
# Elapsed time in update: 2.200780
# Elapsed time in update: 2.178128
# Iteration: 00012730/01000000
# Elapsed time in update: 2.186124
# Elapsed time in update: 2.175822
# Elapsed time in update: 2.176385
# Elapsed time in update: 2.178978
# Elapsed time in update: 2.169509
# Elapsed time in update: 2.181828
# Elapsed time in update: 2.191354
# Elapsed time in update: 2.202437
# Elapsed time in update: 2.188593
# Elapsed time in update: 2.211144
# Iteration: 00012740/01000000
# Elapsed time in update: 2.182712
# Elapsed time in update: 2.191215
# Elapsed time in update: 2.190018
# Elapsed time in update: 2.203364
# Elapsed time in update: 2.184826
# Elapsed time in update: 2.180535
# Elapsed time in update: 2.195020
# Elapsed time in update: 2.193496
# Elapsed time in update: 2.186630
# Elapsed time in update: 2.193313
# Iteration: 00012750/01000000
# Elapsed time in update: 2.173383
# Elapsed time in update: 2.168985
# Elapsed time in update: 2.192700
# Elapsed time in update: 2.195123
# Elapsed time in update: 2.186155
# Elapsed time in update: 2.196970
# Elapsed time in update: 2.171091
# Elapsed time in update: 2.196978
# Elapsed time in update: 2.183141
# Elapsed time in update: 2.220464
# Iteration: 00012760/01000000
# Elapsed time in update: 2.169881
# Elapsed time in update: 2.212978
# Elapsed time in update: 2.202676
# Elapsed time in update: 2.189628
# Elapsed time in update: 2.167972
# Elapsed time in update: 2.204724
# Elapsed time in update: 2.200332
# Elapsed time in update: 2.191792
# Elapsed time in update: 2.185246
# Elapsed time in update: 2.176327
# Iteration: 00012770/01000000
# Elapsed time in update: 2.195350
# Elapsed time in update: 2.208327
# Elapsed time in update: 2.183528
# Elapsed time in update: 2.171347
# Elapsed time in update: 2.211414
# Elapsed time in update: 2.190529
# Elapsed time in update: 2.221199
# Elapsed time in update: 2.239410
# Elapsed time in update: 2.188502
# Elapsed time in update: 2.190396
# Iteration: 00012780/01000000
# Elapsed time in update: 2.177735
# Elapsed time in update: 2.181689
# Elapsed time in update: 2.209438
# Elapsed time in update: 2.193645
# Elapsed time in update: 2.201454
# Elapsed time in update: 2.187327
# Elapsed time in update: 2.190204
# Elapsed time in update: 2.221702
# Elapsed time in update: 2.179672
# Elapsed time in update: 2.172966
# Iteration: 00012790/01000000
# Elapsed time in update: 2.194968
# Elapsed time in update: 2.183579
# Elapsed time in update: 2.210368
# Elapsed time in update: 2.195155
# Elapsed time in update: 2.188982
# Elapsed time in update: 2.223544
# Elapsed time in update: 2.181321
# Elapsed time in update: 2.185843
# Elapsed time in update: 2.186805
# Elapsed time in update: 2.197614
# Iteration: 00012800/01000000
# Elapsed time in update: 2.194349
# Elapsed time in update: 2.210277
# Elapsed time in update: 2.195823
# Elapsed time in update: 2.209491
# Elapsed time in update: 2.199306
# Elapsed time in update: 2.189810
# Elapsed time in update: 2.211213
# Elapsed time in update: 2.194963
# Elapsed time in update: 2.200742
# Elapsed time in update: 2.189897
# Iteration: 00012810/01000000
# Elapsed time in update: 2.218505
# Elapsed time in update: 2.224260
# Elapsed time in update: 2.192082
# Elapsed time in update: 2.207969
# Elapsed time in update: 2.200070
# Elapsed time in update: 2.200134
# Elapsed time in update: 2.226108
# Elapsed time in update: 2.206550
# Elapsed time in update: 2.193565
# Elapsed time in update: 2.182293
# Iteration: 00012820/01000000
# Elapsed time in update: 2.203185
# Elapsed time in update: 2.220078
# Elapsed time in update: 2.233215
# Elapsed time in update: 2.186914
# Elapsed time in update: 2.206152
# Elapsed time in update: 2.198627
# Elapsed time in update: 2.214402
# Elapsed time in update: 2.199292
# Elapsed time in update: 2.204536
# Elapsed time in update: 2.225766
# Iteration: 00012830/01000000
# Elapsed time in update: 2.199598
# Elapsed time in update: 2.183448
# Elapsed time in update: 2.202209
# Elapsed time in update: 2.200772
# Elapsed time in update: 2.214410
# Elapsed time in update: 2.195334
# Elapsed time in update: 2.195424
# Elapsed time in update: 2.215388
# Elapsed time in update: 2.193915
# Elapsed time in update: 2.203253
# Iteration: 00012840/01000000
# Elapsed time in update: 2.192901
# Elapsed time in update: 2.204732
# Elapsed time in update: 2.216076
# Elapsed time in update: 2.191336
# Elapsed time in update: 2.196206
# Elapsed time in update: 2.213614
# Elapsed time in update: 2.212928
# Elapsed time in update: 2.193007
# Elapsed time in update: 2.192965
# Elapsed time in update: 2.221354
# Iteration: 00012850/01000000
# Elapsed time in update: 2.200176
# Elapsed time in update: 2.207250
# Elapsed time in update: 2.221718
# Elapsed time in update: 2.227448
# Elapsed time in update: 2.177017
# Elapsed time in update: 2.231666
# Elapsed time in update: 2.208142
# Elapsed time in update: 2.206016
# Elapsed time in update: 2.198932
# Elapsed time in update: 2.195465
# Iteration: 00012860/01000000
# Elapsed time in update: 2.185518
# Elapsed time in update: 2.212081
# Elapsed time in update: 2.203806
# Elapsed time in update: 2.216779
# Elapsed time in update: 2.189818
# Elapsed time in update: 2.208429
# Elapsed time in update: 2.197910
# Elapsed time in update: 2.223838
# Elapsed time in update: 2.219474
# Elapsed time in update: 2.224128
# Iteration: 00012870/01000000
# Elapsed time in update: 2.185125
# Elapsed time in update: 2.184364
# Elapsed time in update: 2.230569
# Elapsed time in update: 2.198392
# Elapsed time in update: 2.200393
# Elapsed time in update: 2.188642
# Elapsed time in update: 2.195858
# Elapsed time in update: 2.190592
# Elapsed time in update: 2.197509
# Elapsed time in update: 2.211504
# Iteration: 00012880/01000000
# Elapsed time in update: 2.198261
# Elapsed time in update: 2.214719
# Elapsed time in update: 2.207928
# Elapsed time in update: 2.190458
# Elapsed time in update: 2.209312
# Elapsed time in update: 2.225618
# Elapsed time in update: 2.188939
# Elapsed time in update: 2.201137
# Elapsed time in update: 2.195516
# Elapsed time in update: 2.205460
# Iteration: 00012890/01000000
# Elapsed time in update: 2.195116
# Elapsed time in update: 2.190902
# Elapsed time in update: 2.203695
# Elapsed time in update: 2.211814
# Elapsed time in update: 2.224468
# Elapsed time in update: 2.192961
# Elapsed time in update: 2.207002
# Elapsed time in update: 2.219282
# Elapsed time in update: 2.201782
# Elapsed time in update: 2.199993
# Iteration: 00012900/01000000
# Elapsed time in update: 2.195607
# Elapsed time in update: 2.203982
# Elapsed time in update: 2.209892
# Elapsed time in update: 2.196004
# Elapsed time in update: 2.194698
# Elapsed time in update: 2.200807
# Elapsed time in update: 2.215475
# Elapsed time in update: 2.202983
# Elapsed time in update: 2.222857
# Elapsed time in update: 2.203954
# Iteration: 00012910/01000000
# Elapsed time in update: 2.191356
# Elapsed time in update: 2.197548
# Elapsed time in update: 2.223252
# Elapsed time in update: 2.225130
# Elapsed time in update: 2.218315
# Elapsed time in update: 2.195295
# Elapsed time in update: 2.206435
# Elapsed time in update: 2.200547
# Elapsed time in update: 2.191401
# Elapsed time in update: 2.206598
# Iteration: 00012920/01000000
# Elapsed time in update: 2.210299
# Elapsed time in update: 2.205297
# Elapsed time in update: 2.211781
# Elapsed time in update: 2.193320
# Elapsed time in update: 2.217353
# Elapsed time in update: 2.211138
# Elapsed time in update: 2.199663
# Elapsed time in update: 2.206635
# Elapsed time in update: 2.248146
# Elapsed time in update: 2.202056
# Iteration: 00012930/01000000
# Elapsed time in update: 2.197269
# Elapsed time in update: 2.214195
# Elapsed time in update: 2.217404
# Elapsed time in update: 2.208973
# Elapsed time in update: 2.207363
# Elapsed time in update: 2.193798
# Elapsed time in update: 2.207880
# Elapsed time in update: 2.199284
# Elapsed time in update: 2.212861
# Elapsed time in update: 2.219912
# Iteration: 00012940/01000000
# Elapsed time in update: 2.206131
# Elapsed time in update: 2.216709
# Elapsed time in update: 2.180701
# Elapsed time in update: 2.190221
# Elapsed time in update: 2.203703
# Elapsed time in update: 2.200477
# Elapsed time in update: 2.201781
# Elapsed time in update: 2.223204
# Elapsed time in update: 2.202446
# Elapsed time in update: 2.205616
# Iteration: 00012950/01000000
# Elapsed time in update: 2.219476
# Elapsed time in update: 2.194958
# Elapsed time in update: 2.196590
# Elapsed time in update: 2.201355
# Elapsed time in update: 2.204834
# Elapsed time in update: 2.190438
# Elapsed time in update: 2.221915
# Elapsed time in update: 2.198545
# Elapsed time in update: 2.201941
# Elapsed time in update: 2.189135
# Iteration: 00012960/01000000
# Elapsed time in update: 2.197201
# Elapsed time in update: 2.234408
# Elapsed time in update: 2.207485
# Elapsed time in update: 2.207943
# Elapsed time in update: 2.191537
# Elapsed time in update: 2.185037
# Elapsed time in update: 2.206591
# Elapsed time in update: 2.255424
# Elapsed time in update: 2.205490
# Elapsed time in update: 2.195626
# Iteration: 00012970/01000000
# Elapsed time in update: 2.200209
# Elapsed time in update: 2.204650
# Elapsed time in update: 2.210502
# Elapsed time in update: 2.216190
# Elapsed time in update: 2.188542
# Elapsed time in update: 2.200443
# Elapsed time in update: 2.203004
# Elapsed time in update: 2.202309
# Elapsed time in update: 2.210944
# Elapsed time in update: 2.212070
# Iteration: 00012980/01000000
# Elapsed time in update: 2.189032
# Elapsed time in update: 2.205612
# Elapsed time in update: 2.211664
# Elapsed time in update: 2.192917
# Elapsed time in update: 2.205267
# Elapsed time in update: 2.215235
# Elapsed time in update: 2.196742
# Elapsed time in update: 2.271540
# Elapsed time in update: 2.208926
# Elapsed time in update: 2.203845
# Iteration: 00012990/01000000
# Elapsed time in update: 2.185825
# Elapsed time in update: 2.218281
# Elapsed time in update: 2.221909
# Elapsed time in update: 2.201763
# Elapsed time in update: 2.196165
# Elapsed time in update: 2.202750
# Elapsed time in update: 2.194270
# Elapsed time in update: 2.203644
# Elapsed time in update: 2.205252
# Elapsed time in update: 2.234880
# Iteration: 00013000/01000000
# Saving images to ./outputs/unit_day2night4/images
# Saving pre-trained checkpoint to ./outputs/unit_day2night4/checkpoints
# Elapsed time in update: 2.250423
# Elapsed time in update: 2.191678
# Elapsed time in update: 2.262455
# Elapsed time in update: 2.214352
# Elapsed time in update: 2.236292
# Elapsed time in update: 2.231529
# Elapsed time in update: 2.205462
# Elapsed time in update: 2.188805
# Elapsed time in update: 2.231920
# Elapsed time in update: 2.194108
# Iteration: 00013010/01000000
# Elapsed time in update: 2.197801
# Elapsed time in update: 2.213739
# Elapsed time in update: 2.209988
# Elapsed time in update: 2.208110
# Elapsed time in update: 2.210433
# Elapsed time in update: 2.218360
# Elapsed time in update: 2.210820
# Elapsed time in update: 2.210415
# Elapsed time in update: 2.201331
# Elapsed time in update: 2.194377
# Iteration: 00013020/01000000
# Elapsed time in update: 2.186331
# Elapsed time in update: 2.234567
# Elapsed time in update: 2.212668
# Elapsed time in update: 2.227240
# Elapsed time in update: 2.209183
# Elapsed time in update: 2.203522
# Elapsed time in update: 2.199013
# Elapsed time in update: 2.215805
# Elapsed time in update: 2.210386
# Elapsed time in update: 2.193323
# Iteration: 00013030/01000000
# Elapsed time in update: 2.185830
# Elapsed time in update: 2.197939
# Elapsed time in update: 2.198633
# Elapsed time in update: 2.210343
# Elapsed time in update: 2.222202
# Elapsed time in update: 2.204394
# Elapsed time in update: 2.193772
# Elapsed time in update: 2.196353
# Elapsed time in update: 2.196807
# Elapsed time in update: 2.202030
# Iteration: 00013040/01000000
# Elapsed time in update: 2.232920
# Elapsed time in update: 2.224080
# Elapsed time in update: 2.188998
# Elapsed time in update: 2.199160
# Elapsed time in update: 2.190453
# Elapsed time in update: 2.186412
# Elapsed time in update: 2.201157
# Elapsed time in update: 2.216455
# Elapsed time in update: 2.208019
# Elapsed time in update: 2.195815
# Iteration: 00013050/01000000
# Elapsed time in update: 2.233003
# Elapsed time in update: 2.208650
# Elapsed time in update: 2.188159
# Elapsed time in update: 2.188926
# Elapsed time in update: 2.206408
# Elapsed time in update: 2.187050
# Elapsed time in update: 2.207321
# Elapsed time in update: 2.216949
# Elapsed time in update: 2.211884
# Elapsed time in update: 2.222751
# Iteration: 00013060/01000000
# Elapsed time in update: 2.209341
# Elapsed time in update: 2.213867
# Elapsed time in update: 2.198316
# Elapsed time in update: 2.215125
# Elapsed time in update: 2.239743
# Elapsed time in update: 2.196443
# Elapsed time in update: 2.245476
# Elapsed time in update: 2.228261
# Elapsed time in update: 2.244020
# Elapsed time in update: 2.193352
# Iteration: 00013070/01000000
# Elapsed time in update: 2.185481
# Elapsed time in update: 2.227090
# Elapsed time in update: 2.197974
# Elapsed time in update: 2.237266
# Elapsed time in update: 2.215451
# Elapsed time in update: 2.218321
# Elapsed time in update: 2.228273
# Elapsed time in update: 2.192828
# Elapsed time in update: 2.198434
# Elapsed time in update: 2.203347
# Iteration: 00013080/01000000
# Elapsed time in update: 2.194515
# Elapsed time in update: 2.191618
# Elapsed time in update: 2.213320
# Elapsed time in update: 2.192342
# Elapsed time in update: 2.196520
# Elapsed time in update: 2.227707
# Elapsed time in update: 2.220501
# Elapsed time in update: 2.225751
# Elapsed time in update: 2.184853
# Elapsed time in update: 2.187830
# Iteration: 00013090/01000000
# Elapsed time in update: 2.203831
# Elapsed time in update: 2.205873
# Elapsed time in update: 2.199635
# Elapsed time in update: 2.193818
# Elapsed time in update: 2.220258
# Elapsed time in update: 2.190434
# Elapsed time in update: 2.197580
# Elapsed time in update: 2.201555
# Elapsed time in update: 2.212445
# Elapsed time in update: 2.210467
# Iteration: 00013100/01000000
# Elapsed time in update: 2.188292
# Elapsed time in update: 2.192480
# Elapsed time in update: 2.222265
# Elapsed time in update: 2.201645
# Elapsed time in update: 2.193055
# Elapsed time in update: 2.194859
# Elapsed time in update: 2.227337
# Elapsed time in update: 2.194318
# Elapsed time in update: 2.202657
# Elapsed time in update: 2.219984
# Iteration: 00013110/01000000
# Elapsed time in update: 2.223537
# Elapsed time in update: 2.183100
# Elapsed time in update: 2.194613
# Elapsed time in update: 2.202693
# Elapsed time in update: 2.208029
# Elapsed time in update: 2.194212
# Elapsed time in update: 2.190560
# Elapsed time in update: 2.190122
# Elapsed time in update: 2.223695
# Elapsed time in update: 2.208359
# Iteration: 00013120/01000000
# Elapsed time in update: 2.238868
# Elapsed time in update: 2.200738
# Elapsed time in update: 2.205044
# Elapsed time in update: 2.207477
# Elapsed time in update: 2.187652
# Elapsed time in update: 2.220333
# Elapsed time in update: 2.247134
# Elapsed time in update: 2.216774
# Elapsed time in update: 2.204491
# Elapsed time in update: 2.227679
# Iteration: 00013130/01000000
# Elapsed time in update: 2.190523
# Elapsed time in update: 2.239898
# Elapsed time in update: 2.187915
# Elapsed time in update: 2.221754
# Elapsed time in update: 2.218694
# Elapsed time in update: 2.200468
# Elapsed time in update: 2.207871
# Elapsed time in update: 2.196728
# Elapsed time in update: 2.222238
# Elapsed time in update: 2.189824
# Iteration: 00013140/01000000
# Elapsed time in update: 2.195771
# Elapsed time in update: 2.220564
# Elapsed time in update: 2.204616
# Elapsed time in update: 2.211557
# Elapsed time in update: 2.193224
# Elapsed time in update: 2.210246
# Elapsed time in update: 2.198287
# Elapsed time in update: 2.201197
# Elapsed time in update: 2.196527
# Elapsed time in update: 2.187678
# Iteration: 00013150/01000000
# Elapsed time in update: 2.197598
# Elapsed time in update: 2.211105
# Elapsed time in update: 2.218568
# Elapsed time in update: 2.206786
# Elapsed time in update: 2.209679
# Elapsed time in update: 2.200020
# Elapsed time in update: 2.214095
# Elapsed time in update: 2.214191
# Elapsed time in update: 2.217340
# Elapsed time in update: 2.196872
# Iteration: 00013160/01000000
# Elapsed time in update: 2.196648
# Elapsed time in update: 2.210552
# Elapsed time in update: 2.185376
# Elapsed time in update: 2.201946
# Elapsed time in update: 2.212613
# Elapsed time in update: 2.210236
# Elapsed time in update: 2.204816
# Elapsed time in update: 2.188185
# Elapsed time in update: 2.248941
# Elapsed time in update: 2.208583
# Iteration: 00013170/01000000
# Elapsed time in update: 2.200667
# Elapsed time in update: 2.207275
# Elapsed time in update: 2.196695
# Elapsed time in update: 2.181873
# Elapsed time in update: 2.205326
# Elapsed time in update: 2.216854
# Elapsed time in update: 2.202528
# Elapsed time in update: 2.199275
# Elapsed time in update: 2.199302
# Elapsed time in update: 2.188125
# Iteration: 00013180/01000000
# Elapsed time in update: 2.227295
# Elapsed time in update: 2.199127
# Elapsed time in update: 2.194114
# Elapsed time in update: 2.197828
# Elapsed time in update: 2.200306
# Elapsed time in update: 2.223110
# Elapsed time in update: 2.203189
# Elapsed time in update: 2.206154
# Elapsed time in update: 2.199925
# Elapsed time in update: 2.195934
# Iteration: 00013190/01000000
# Elapsed time in update: 2.182119
# Elapsed time in update: 2.199790
# Elapsed time in update: 2.192278
# Elapsed time in update: 2.175696
# Elapsed time in update: 2.176684
# Elapsed time in update: 2.243242
# Elapsed time in update: 2.197808
# Elapsed time in update: 2.197804
# Elapsed time in update: 2.230804
# Elapsed time in update: 2.203238
# Iteration: 00013200/01000000
# Elapsed time in update: 2.188776
# Elapsed time in update: 2.200196
# Elapsed time in update: 2.196157
# Elapsed time in update: 2.208571
# Elapsed time in update: 2.224568
# Elapsed time in update: 2.193865
# Elapsed time in update: 2.216789
# Elapsed time in update: 2.189658
# Elapsed time in update: 2.193455
# Elapsed time in update: 2.188635
# Iteration: 00013210/01000000
# Elapsed time in update: 2.185767
# Elapsed time in update: 2.195871
# Elapsed time in update: 2.232370
# Elapsed time in update: 2.215486
# Elapsed time in update: 2.208698
# Elapsed time in update: 2.199318
# Elapsed time in update: 2.180360
# Elapsed time in update: 2.239147
# Elapsed time in update: 2.186093
# Elapsed time in update: 2.195757
# Iteration: 00013220/01000000
# Elapsed time in update: 2.213898
# Elapsed time in update: 2.186840
# Elapsed time in update: 2.195054
# Elapsed time in update: 2.203838
# Elapsed time in update: 2.221344
# Elapsed time in update: 2.223624
# Elapsed time in update: 2.180433
# Elapsed time in update: 2.197535
# Elapsed time in update: 2.204120
# Elapsed time in update: 2.235949
# Iteration: 00013230/01000000
# Elapsed time in update: 2.197205
# Elapsed time in update: 2.227425
# Elapsed time in update: 2.209279
# Elapsed time in update: 2.210129
# Elapsed time in update: 2.234593
# Elapsed time in update: 2.218952
# Elapsed time in update: 2.182366
# Elapsed time in update: 2.204859
# Elapsed time in update: 2.203829
# Elapsed time in update: 2.211206
# Iteration: 00013240/01000000
# Elapsed time in update: 2.214906
# Elapsed time in update: 2.194625
# Elapsed time in update: 2.201781
# Elapsed time in update: 2.256984
# Elapsed time in update: 2.242253
# Elapsed time in update: 2.207942
# Elapsed time in update: 2.221012
# Elapsed time in update: 2.203712
# Elapsed time in update: 2.240432
# Elapsed time in update: 2.224792
# Iteration: 00013250/01000000
# Elapsed time in update: 2.209798
# Elapsed time in update: 2.198421
# Elapsed time in update: 2.226435
# Elapsed time in update: 2.208715
# Elapsed time in update: 2.219099
# Elapsed time in update: 2.199523
# Elapsed time in update: 2.212298
# Elapsed time in update: 2.205647
# Elapsed time in update: 2.213494
# Elapsed time in update: 2.220718
# Iteration: 00013260/01000000
# Elapsed time in update: 2.208918
# Elapsed time in update: 2.203712
# Elapsed time in update: 2.203848
# Elapsed time in update: 2.199816
# Elapsed time in update: 2.189866
# Elapsed time in update: 2.201931
# Elapsed time in update: 2.202428
# Elapsed time in update: 2.191650
# Elapsed time in update: 2.206615
# Elapsed time in update: 2.219630
# Iteration: 00013270/01000000
# Elapsed time in update: 2.205854
# Elapsed time in update: 2.196563
# Elapsed time in update: 2.206791
# Elapsed time in update: 2.193366
# Elapsed time in update: 2.204051
# Elapsed time in update: 2.190347
# Elapsed time in update: 2.216454
# Elapsed time in update: 2.197565
# Elapsed time in update: 2.205390
# Elapsed time in update: 2.228793
# Iteration: 00013280/01000000
# Elapsed time in update: 2.207815
# Elapsed time in update: 2.172359
# Elapsed time in update: 2.187842
# Elapsed time in update: 2.204478
# Elapsed time in update: 2.209933
# Elapsed time in update: 2.213963
# Elapsed time in update: 2.194260
# Elapsed time in update: 2.221352
# Elapsed time in update: 2.204362
# Elapsed time in update: 2.192620
# Iteration: 00013290/01000000
# Elapsed time in update: 2.195629
# Elapsed time in update: 2.187351
# Elapsed time in update: 2.195006
# Elapsed time in update: 2.195808
# Elapsed time in update: 2.199660
# Elapsed time in update: 2.209422
# Elapsed time in update: 2.187835
# Elapsed time in update: 2.197658
# Elapsed time in update: 2.195873
# Elapsed time in update: 2.211412
# Iteration: 00013300/01000000
# Elapsed time in update: 2.203636
# Elapsed time in update: 2.206335
# Elapsed time in update: 2.205371
# Elapsed time in update: 2.201248
# Elapsed time in update: 2.237483
# Elapsed time in update: 2.215918
# Elapsed time in update: 2.204328
# Elapsed time in update: 2.195718
# Elapsed time in update: 2.223449
# Elapsed time in update: 2.205656
# Iteration: 00013310/01000000
# Elapsed time in update: 2.237330
# Elapsed time in update: 2.202169
# Elapsed time in update: 2.228738
# Elapsed time in update: 2.214041
# Elapsed time in update: 2.193902
# Elapsed time in update: 2.193022
# Elapsed time in update: 2.205432
# Elapsed time in update: 2.221205
# Elapsed time in update: 2.228144
# Elapsed time in update: 2.215239
# Iteration: 00013320/01000000
# Elapsed time in update: 2.210013
# Elapsed time in update: 2.200145
# Elapsed time in update: 2.220270
# Elapsed time in update: 2.183221
# Elapsed time in update: 2.199801
# Elapsed time in update: 2.215641
# Elapsed time in update: 2.212063
# Elapsed time in update: 2.211400
# Elapsed time in update: 2.211683
# Elapsed time in update: 2.186674
# Iteration: 00013330/01000000
# Elapsed time in update: 2.202702
# Elapsed time in update: 2.244028
# Elapsed time in update: 2.197153
# Elapsed time in update: 2.188137
# Elapsed time in update: 2.200845
# Elapsed time in update: 2.203886
# Elapsed time in update: 2.202609
# Elapsed time in update: 2.200559
# Elapsed time in update: 2.209910
# Elapsed time in update: 2.212246
# Iteration: 00013340/01000000
# Elapsed time in update: 2.190017
# Elapsed time in update: 2.210141
# Elapsed time in update: 2.198766
# Elapsed time in update: 2.202045
# Elapsed time in update: 2.216321
# Elapsed time in update: 2.196762
# Elapsed time in update: 2.197287
# Elapsed time in update: 2.204101
# Elapsed time in update: 2.228049
# Elapsed time in update: 2.199198
# Iteration: 00013350/01000000
# Elapsed time in update: 2.193987
# Elapsed time in update: 2.200063
# Elapsed time in update: 2.196987
# Elapsed time in update: 2.206309
# Elapsed time in update: 2.227254
# Elapsed time in update: 2.192692
# Elapsed time in update: 2.198711
# Elapsed time in update: 2.188017
# Elapsed time in update: 2.219069
# Elapsed time in update: 2.209263
# Iteration: 00013360/01000000
# Elapsed time in update: 2.203270
# Elapsed time in update: 2.201912
# Elapsed time in update: 2.226321
# Elapsed time in update: 2.178922
# Elapsed time in update: 2.453669
# Elapsed time in update: 2.196324
# Elapsed time in update: 2.193745
# Elapsed time in update: 2.200900
# Elapsed time in update: 2.198226
# Elapsed time in update: 2.213854
# Iteration: 00013370/01000000
# Elapsed time in update: 2.195045
# Elapsed time in update: 2.204407
# Elapsed time in update: 2.194985
# Elapsed time in update: 2.184632
# Elapsed time in update: 2.206011
# Elapsed time in update: 2.216456
# Elapsed time in update: 2.212997
# Elapsed time in update: 2.198117
# Elapsed time in update: 2.197125
# Elapsed time in update: 2.183893
# Iteration: 00013380/01000000
# Elapsed time in update: 2.191474
# Elapsed time in update: 2.216137
# Elapsed time in update: 2.201061
# Elapsed time in update: 2.218462
# Elapsed time in update: 2.187758
# Elapsed time in update: 2.197313
# Elapsed time in update: 2.208576
# Elapsed time in update: 2.216707
# Elapsed time in update: 2.208083
# Elapsed time in update: 2.202082
# Iteration: 00013390/01000000
# Elapsed time in update: 2.212646
# Elapsed time in update: 2.233600
# Elapsed time in update: 2.207841
# Elapsed time in update: 2.184984
# Elapsed time in update: 2.198382
# Elapsed time in update: 2.181646
# Elapsed time in update: 2.201838
# Elapsed time in update: 2.216556
# Elapsed time in update: 2.211863
# Elapsed time in update: 2.213012
# Iteration: 00013400/01000000
# Elapsed time in update: 2.203561
# Elapsed time in update: 2.206613
# Elapsed time in update: 2.201213
# Elapsed time in update: 2.198953
# Elapsed time in update: 2.214110
# Elapsed time in update: 2.192567
# Elapsed time in update: 2.199111
# Elapsed time in update: 2.193347
# Elapsed time in update: 2.189054
# Elapsed time in update: 2.198779
# Iteration: 00013410/01000000
# Elapsed time in update: 2.226531
# Elapsed time in update: 2.193737
# Elapsed time in update: 2.202748
# Elapsed time in update: 2.193292
# Elapsed time in update: 2.215322
# Elapsed time in update: 2.214969
# Elapsed time in update: 2.222558
# Elapsed time in update: 2.187337
# Elapsed time in update: 2.204681
# Elapsed time in update: 2.193168
# Iteration: 00013420/01000000
# Elapsed time in update: 2.206387
# Elapsed time in update: 2.205893
# Elapsed time in update: 2.203947
# Elapsed time in update: 2.194359
# Elapsed time in update: 2.199062
# Elapsed time in update: 2.246824
# Elapsed time in update: 2.189642
# Elapsed time in update: 2.201946
# Elapsed time in update: 2.207000
# Elapsed time in update: 2.191293
# Iteration: 00013430/01000000
# Elapsed time in update: 2.196105
# Elapsed time in update: 2.204441
# Elapsed time in update: 2.203972
# Elapsed time in update: 2.202998
# Elapsed time in update: 2.246381
# Elapsed time in update: 2.213319
# Elapsed time in update: 2.190753
# Elapsed time in update: 2.215207
# Elapsed time in update: 2.235276
# Elapsed time in update: 2.201239
# Iteration: 00013440/01000000
# Elapsed time in update: 2.202875
# Elapsed time in update: 2.244093
# Elapsed time in update: 2.195350
# Elapsed time in update: 2.198251
# Elapsed time in update: 2.197610
# Elapsed time in update: 2.231852
# Elapsed time in update: 2.195398
# Elapsed time in update: 2.202012
# Elapsed time in update: 2.216513
# Elapsed time in update: 2.202727
# Iteration: 00013450/01000000
# Elapsed time in update: 2.197459
# Elapsed time in update: 2.193919
# Elapsed time in update: 2.221352
# Elapsed time in update: 2.205693
# Elapsed time in update: 2.202299
# Elapsed time in update: 2.192444
# Elapsed time in update: 2.194047
# Elapsed time in update: 2.201475
# Elapsed time in update: 2.199604
# Elapsed time in update: 2.211934
# Iteration: 00013460/01000000
# Elapsed time in update: 2.208075
# Elapsed time in update: 2.221818
# Elapsed time in update: 2.216507
# Elapsed time in update: 2.186131
# Elapsed time in update: 2.206900
# Elapsed time in update: 2.190058
# Elapsed time in update: 2.184661
# Elapsed time in update: 2.194487
# Elapsed time in update: 2.195646
# Elapsed time in update: 2.201639
# Iteration: 00013470/01000000
# Elapsed time in update: 2.183990
# Elapsed time in update: 2.183753
# Elapsed time in update: 2.182899
# Elapsed time in update: 2.204095
# Elapsed time in update: 2.183380
# Elapsed time in update: 2.190634
# Elapsed time in update: 2.193093
# Elapsed time in update: 2.191946
# Elapsed time in update: 2.193846
# Elapsed time in update: 2.179957
# Iteration: 00013480/01000000
# Elapsed time in update: 2.179989
# Elapsed time in update: 2.191827
# Elapsed time in update: 2.201124
# Elapsed time in update: 2.177258
# Elapsed time in update: 2.184124
# Elapsed time in update: 2.194870
# Elapsed time in update: 2.181481
# Elapsed time in update: 2.191137
# Elapsed time in update: 2.190677
# Elapsed time in update: 2.196517
# Iteration: 00013490/01000000
# Elapsed time in update: 2.204725
# Elapsed time in update: 2.185088
# Elapsed time in update: 2.164357
# Elapsed time in update: 2.198640
# Elapsed time in update: 2.215740
# Elapsed time in update: 2.201009
# Elapsed time in update: 2.197025
# Elapsed time in update: 2.179775
# Elapsed time in update: 2.172001
# Elapsed time in update: 2.183296
# Iteration: 00013500/01000000
# Saving images to ./outputs/unit_day2night4/images
# Saving pre-trained checkpoint to ./outputs/unit_day2night4/checkpoints
# Elapsed time in update: 2.222197
# Elapsed time in update: 2.189812
# Elapsed time in update: 2.181302
# Elapsed time in update: 2.268130
# Elapsed time in update: 2.242474
# Elapsed time in update: 2.196238
# Elapsed time in update: 2.177916
# Elapsed time in update: 2.206934
# Elapsed time in update: 2.183063
# Elapsed time in update: 2.183912
# Iteration: 00013510/01000000
# Elapsed time in update: 2.176806
# Elapsed time in update: 2.176852
# Elapsed time in update: 2.173794
# Elapsed time in update: 2.183280
# Elapsed time in update: 2.174986
# Elapsed time in update: 2.198288
# Elapsed time in update: 2.176479
# Elapsed time in update: 2.194180
# Elapsed time in update: 2.199150
# Elapsed time in update: 2.203663
# Iteration: 00013520/01000000
# Elapsed time in update: 2.193537
# Elapsed time in update: 2.192834
# Elapsed time in update: 2.225973
# Elapsed time in update: 2.180062
# Elapsed time in update: 2.215049
# Elapsed time in update: 2.202948
# Elapsed time in update: 2.186459
# Elapsed time in update: 2.191625
# Elapsed time in update: 2.177514
# Elapsed time in update: 2.199111
# Iteration: 00013530/01000000
# Elapsed time in update: 2.185261
# Elapsed time in update: 2.204067
# Elapsed time in update: 2.200015
# Elapsed time in update: 2.196348
# Elapsed time in update: 2.225412
# Elapsed time in update: 2.200231
# Elapsed time in update: 2.186649
# Elapsed time in update: 2.200709
# Elapsed time in update: 2.196300
# Elapsed time in update: 2.181588
# Iteration: 00013540/01000000
# Elapsed time in update: 2.182907
# Elapsed time in update: 2.185292
# Elapsed time in update: 2.200823
# Elapsed time in update: 2.219288
# Elapsed time in update: 2.195557
# Elapsed time in update: 2.215930
# Elapsed time in update: 2.201549
# Elapsed time in update: 2.197779
# Elapsed time in update: 2.186700
# Elapsed time in update: 2.199603
# Iteration: 00013550/01000000
# Elapsed time in update: 2.231872
# Elapsed time in update: 2.195524
# Elapsed time in update: 2.181752
# Elapsed time in update: 2.195994
# Elapsed time in update: 2.205248
# Elapsed time in update: 2.216682
# Elapsed time in update: 2.198963
# Elapsed time in update: 2.198701
# Elapsed time in update: 2.189461
# Elapsed time in update: 2.208187
# Iteration: 00013560/01000000
# Elapsed time in update: 2.183304
# Elapsed time in update: 2.185983
# Elapsed time in update: 2.187431
# Elapsed time in update: 2.193177
# Elapsed time in update: 2.192618
# Elapsed time in update: 2.195334
# Elapsed time in update: 2.190560
# Elapsed time in update: 2.205506
# Elapsed time in update: 2.181366
# Elapsed time in update: 2.187521
# Iteration: 00013570/01000000
# Elapsed time in update: 2.184736
# Elapsed time in update: 2.176239
# Elapsed time in update: 2.190825
# Elapsed time in update: 2.188107
# Elapsed time in update: 2.171743
# Elapsed time in update: 2.196543
# Elapsed time in update: 2.187674
# Elapsed time in update: 2.189785
# Elapsed time in update: 2.195909
# Elapsed time in update: 2.209555
# Iteration: 00013580/01000000
# Elapsed time in update: 2.204316
# Elapsed time in update: 2.199241
# Elapsed time in update: 2.201054
# Elapsed time in update: 2.186697
# Elapsed time in update: 2.189139
# Elapsed time in update: 2.182117
# Elapsed time in update: 2.176392
# Elapsed time in update: 2.221298
# Elapsed time in update: 2.237058
# Elapsed time in update: 2.184639
# Iteration: 00013590/01000000
# Elapsed time in update: 2.175328
# Elapsed time in update: 2.200845
# Elapsed time in update: 2.211883
# Elapsed time in update: 2.178035
# Elapsed time in update: 2.230519
# Elapsed time in update: 2.173039
# Elapsed time in update: 2.214812
# Elapsed time in update: 2.203382
# Elapsed time in update: 2.200357
# Elapsed time in update: 2.184027
# Iteration: 00013600/01000000
# Elapsed time in update: 2.171273
# Elapsed time in update: 2.203812
# Elapsed time in update: 2.226301
# Elapsed time in update: 2.180006
# Elapsed time in update: 2.178683
# Elapsed time in update: 2.200531
# Elapsed time in update: 2.194348
# Elapsed time in update: 2.199009
# Elapsed time in update: 2.183764
# Elapsed time in update: 2.196231
# Iteration: 00013610/01000000
# Elapsed time in update: 2.188908
# Elapsed time in update: 2.212522
# Elapsed time in update: 2.205291
# Elapsed time in update: 2.188727
# Elapsed time in update: 2.180826
# Elapsed time in update: 2.213083
# Elapsed time in update: 2.217833
# Elapsed time in update: 2.203104
# Elapsed time in update: 2.198590
# Elapsed time in update: 2.189305
# Iteration: 00013620/01000000
# Elapsed time in update: 2.188829
# Elapsed time in update: 2.212445
# Elapsed time in update: 2.202381
# Elapsed time in update: 2.197645
# Elapsed time in update: 2.195673
# Elapsed time in update: 2.196188
# Elapsed time in update: 2.198127
# Elapsed time in update: 2.200249
# Elapsed time in update: 2.201255
# Elapsed time in update: 2.215649
# Iteration: 00013630/01000000
# Elapsed time in update: 2.203119
# Elapsed time in update: 2.201728
# Elapsed time in update: 2.199399
# Elapsed time in update: 2.215903
# Elapsed time in update: 2.194815
# Elapsed time in update: 2.198933
# Elapsed time in update: 2.193396
# Elapsed time in update: 2.204926
# Elapsed time in update: 2.204966
# Elapsed time in update: 2.239691
# Iteration: 00013640/01000000
# Elapsed time in update: 2.216711
# Elapsed time in update: 2.203284
# Elapsed time in update: 2.182750
# Elapsed time in update: 2.204717
# Elapsed time in update: 2.214439
# Elapsed time in update: 2.219715
# Elapsed time in update: 2.196171
# Elapsed time in update: 2.193131
# Elapsed time in update: 2.213019
# Elapsed time in update: 2.200183
# Iteration: 00013650/01000000
# Elapsed time in update: 2.206276
# Elapsed time in update: 2.201376
# Elapsed time in update: 2.182110
# Elapsed time in update: 2.194982
# Elapsed time in update: 2.230531
# Elapsed time in update: 2.195467
# Elapsed time in update: 2.196000
# Elapsed time in update: 2.210790
# Elapsed time in update: 2.185051
# Elapsed time in update: 2.191905
# Iteration: 00013660/01000000
# Elapsed time in update: 2.197390
# Elapsed time in update: 2.196752
# Elapsed time in update: 2.202578
# Elapsed time in update: 2.189649
# Elapsed time in update: 2.208195
# Elapsed time in update: 2.179456
# Elapsed time in update: 2.196596
# Elapsed time in update: 2.190452
# Elapsed time in update: 2.187932
# Elapsed time in update: 2.189823
# Iteration: 00013670/01000000
# Elapsed time in update: 2.189265
# Elapsed time in update: 2.222800
# Elapsed time in update: 2.178697
# Elapsed time in update: 2.200582
# Elapsed time in update: 2.172693
# Elapsed time in update: 2.207710
# Elapsed time in update: 2.195136
# Elapsed time in update: 2.202957
# Elapsed time in update: 2.194512
# Elapsed time in update: 2.195670
# Iteration: 00013680/01000000
# Elapsed time in update: 2.184499
# Elapsed time in update: 2.179323
# Elapsed time in update: 2.179885
# Elapsed time in update: 2.189328
# Elapsed time in update: 2.179053
# Elapsed time in update: 2.180226
# Elapsed time in update: 2.180716
# Elapsed time in update: 2.181951
# Elapsed time in update: 2.184985
# Elapsed time in update: 2.181854
# Iteration: 00013690/01000000
# Elapsed time in update: 2.200077
# Elapsed time in update: 2.192871
# Elapsed time in update: 2.188184
# Elapsed time in update: 2.178475
# Elapsed time in update: 2.189915
# Elapsed time in update: 2.201725
# Elapsed time in update: 2.205738
# Elapsed time in update: 2.197747
# Elapsed time in update: 2.173626
# Elapsed time in update: 2.184696
# Iteration: 00013700/01000000
# Elapsed time in update: 2.191667
# Elapsed time in update: 2.173429
# Elapsed time in update: 2.201041
# Elapsed time in update: 2.175512
# Elapsed time in update: 2.183831
# Elapsed time in update: 2.183705
# Elapsed time in update: 2.174663
# Elapsed time in update: 2.188153
# Elapsed time in update: 2.201260
# Elapsed time in update: 2.205300
# Iteration: 00013710/01000000
# Elapsed time in update: 2.204913
# Elapsed time in update: 2.194456
# Elapsed time in update: 2.202457
# Elapsed time in update: 2.179793
# Elapsed time in update: 2.215071
# Elapsed time in update: 2.197533
# Elapsed time in update: 2.226958
# Elapsed time in update: 2.187351
# Elapsed time in update: 2.218574
# Elapsed time in update: 2.219004
# Iteration: 00013720/01000000
# Elapsed time in update: 2.191724
# Elapsed time in update: 2.188397
# Elapsed time in update: 2.214800
# Elapsed time in update: 2.210754
# Elapsed time in update: 2.191332
# Elapsed time in update: 2.193369
# Elapsed time in update: 2.182431
# Elapsed time in update: 2.184189
# Elapsed time in update: 2.181044
# Elapsed time in update: 2.196376
# Iteration: 00013730/01000000
# Elapsed time in update: 2.192163
# Elapsed time in update: 2.186738
# Elapsed time in update: 2.188715
# Elapsed time in update: 2.221723
# Elapsed time in update: 2.197393
# Elapsed time in update: 2.196767
# Elapsed time in update: 2.193858
# Elapsed time in update: 2.196900
# Elapsed time in update: 2.193531
# Elapsed time in update: 2.181355
# Iteration: 00013740/01000000
# Elapsed time in update: 2.198717
# Elapsed time in update: 2.194922
# Elapsed time in update: 2.217569
# Elapsed time in update: 2.183133
# Elapsed time in update: 2.206309
# Elapsed time in update: 2.217163
# Elapsed time in update: 2.176891
# Elapsed time in update: 2.198935
# Elapsed time in update: 2.198604
# Elapsed time in update: 2.175931
# Iteration: 00013750/01000000
# Elapsed time in update: 2.199686
# Elapsed time in update: 2.174972
# Elapsed time in update: 2.184492
# Elapsed time in update: 2.185740
# Elapsed time in update: 2.180301
# Elapsed time in update: 2.193381
# Elapsed time in update: 2.203865
# Elapsed time in update: 2.206076
# Elapsed time in update: 2.199015
# Elapsed time in update: 2.188810
# Iteration: 00013760/01000000
# Elapsed time in update: 2.177572
# Elapsed time in update: 2.192115
# Elapsed time in update: 2.192559
# Elapsed time in update: 2.177635
# Elapsed time in update: 2.171939
# Elapsed time in update: 2.195212
# Elapsed time in update: 2.192373
# Elapsed time in update: 2.216720
# Elapsed time in update: 2.197375
# Elapsed time in update: 2.209949
# Iteration: 00013770/01000000
# Elapsed time in update: 2.194672
# Elapsed time in update: 2.193010
# Elapsed time in update: 2.183525
# Elapsed time in update: 2.185207
# Elapsed time in update: 2.173755
# Elapsed time in update: 2.192312
# Elapsed time in update: 2.188269
# Elapsed time in update: 2.174398
# Elapsed time in update: 2.170696
# Elapsed time in update: 2.193504
# Iteration: 00013780/01000000
# Elapsed time in update: 2.196388
# Elapsed time in update: 2.203727
# Elapsed time in update: 2.197254
# Elapsed time in update: 2.177924
# Elapsed time in update: 2.180413
# Elapsed time in update: 2.175951
# Elapsed time in update: 2.184133
# Elapsed time in update: 2.184376
# Elapsed time in update: 2.192026
# ...
# Elapsed time in update: 2.195802
# Iteration: 00022480/01000000
# Elapsed time in update: 2.205418
# Elapsed time in update: 2.211216
# Elapsed time in update: 2.195017
# Elapsed time in update: 2.226036
# Elapsed time in update: 2.192338
# Elapsed time in update: 2.199313
# Elapsed time in update: 2.202396
# Elapsed time in update: 2.187716
# Elapsed time in update: 2.218204
# Elapsed time in update: 2.203482
# Iteration: 00022490/01000000
# Elapsed time in update: 2.204990
# Elapsed time in update: 2.197144
# Elapsed time in update: 2.189767
# Elapsed time in update: 2.199789
# Elapsed time in update: 2.196754
# Elapsed time in update: 2.210999
# Elapsed time in update: 2.206976
# Elapsed time in update: 2.236027
# Elapsed time in update: 2.196317
# Elapsed time in update: 2.221669
# Iteration: 00022500/01000000
# Saving images to ./outputs/unit_day2night4/images
# Saving pre-trained checkpoint to ./outputs/unit_day2night4/checkpoints
# Elapsed time in update: 2.371706
# Elapsed time in update: 2.219065
# Elapsed time in update: 2.303515
# Elapsed time in update: 2.195299
# Elapsed time in update: 2.310203
# Elapsed time in update: 2.220739
# Elapsed time in update: 2.195324
# Elapsed time in update: 2.226605
# Elapsed time in update: 2.217102
# Elapsed time in update: 2.211753
# Iteration: 00022510/01000000
# Elapsed time in update: 2.206663
# Elapsed time in update: 2.220309
# Elapsed time in update: 2.198120
# Elapsed time in update: 2.202955
# Elapsed time in update: 2.209462
# Elapsed time in update: 2.226940
# Elapsed time in update: 2.208076
# Elapsed time in update: 2.201310
# Elapsed time in update: 2.187089
# Elapsed time in update: 2.202401
# Iteration: 00022520/01000000
# Elapsed time in update: 2.202000
# Elapsed time in update: 2.217515
# Elapsed time in update: 2.224090
# Elapsed time in update: 2.191124
# Elapsed time in update: 2.230202
# Elapsed time in update: 2.192997
# Elapsed time in update: 2.204960
# Elapsed time in update: 2.191503
# Elapsed time in update: 2.188821
# Elapsed time in update: 2.198894
# Iteration: 00022530/01000000
# Elapsed time in update: 2.201056
# Elapsed time in update: 2.197670
# Elapsed time in update: 2.218383
# Elapsed time in update: 2.197799
# Elapsed time in update: 2.205918
# Elapsed time in update: 2.215381
# Elapsed time in update: 2.184647
# Elapsed time in update: 2.213894
# Elapsed time in update: 2.226036
# Elapsed time in update: 2.204010
# Iteration: 00022540/01000000
# Elapsed time in update: 2.206455
# Elapsed time in update: 2.207720
# Elapsed time in update: 2.207619
# Elapsed time in update: 2.203801
# Elapsed time in update: 2.199713
# Elapsed time in update: 2.198421
# Elapsed time in update: 2.213371
# Elapsed time in update: 2.241536
# Elapsed time in update: 2.195647
# Elapsed time in update: 2.206563
# Iteration: 00022550/01000000
# Elapsed time in update: 2.214503
# Elapsed time in update: 2.218423
# Elapsed time in update: 2.214345
# Elapsed time in update: 2.193974
# Elapsed time in update: 2.197952
# Elapsed time in update: 2.197495
# Elapsed time in update: 2.209881
# Elapsed time in update: 2.210766
# Elapsed time in update: 2.223639
# Elapsed time in update: 2.206068
# Iteration: 00022560/01000000
# Elapsed time in update: 2.221753
# Elapsed time in update: 2.189328
# Elapsed time in update: 2.202293
# Elapsed time in update: 2.190648
# Elapsed time in update: 2.209709
# Elapsed time in update: 2.213849
# Elapsed time in update: 2.197456
# Elapsed time in update: 2.197996
# Elapsed time in update: 2.204654
# Elapsed time in update: 2.199565
# Iteration: 00022570/01000000
# Elapsed time in update: 2.205664
# Elapsed time in update: 2.206223
# Elapsed time in update: 2.216393
# Elapsed time in update: 2.214787
# Elapsed time in update: 2.224205
# Elapsed time in update: 2.204382
# Elapsed time in update: 2.210101
# Elapsed time in update: 2.188172
# Elapsed time in update: 2.174791
# Elapsed time in update: 2.200704
# Iteration: 00022580/01000000
# Elapsed time in update: 2.213351
# Elapsed time in update: 2.223201
# Elapsed time in update: 2.209977
# Elapsed time in update: 2.203480
# Elapsed time in update: 2.180898
# Elapsed time in update: 2.200755
# Elapsed time in update: 2.221354
# Elapsed time in update: 2.216552
# Elapsed time in update: 2.200826
# Elapsed time in update: 2.198151
# Iteration: 00022590/01000000
# Elapsed time in update: 2.181619
# Elapsed time in update: 2.200125
# Elapsed time in update: 2.223781
# Elapsed time in update: 2.199517
# Elapsed time in update: 2.226076
# Elapsed time in update: 2.199563
# Elapsed time in update: 2.200253
# Elapsed time in update: 2.199628
# Elapsed time in update: 2.213505
# Elapsed time in update: 2.186054
# Iteration: 00022600/01000000
# Elapsed time in update: 2.200507
# Elapsed time in update: 2.191566
# Elapsed time in update: 2.209974
# Elapsed time in update: 2.221324
# Elapsed time in update: 2.252158
# Elapsed time in update: 2.184548
# Elapsed time in update: 2.192773
# Elapsed time in update: 2.206034
# Elapsed time in update: 2.225769
# Elapsed time in update: 2.205173
# Iteration: 00022610/01000000
# Elapsed time in update: 2.207555
# Elapsed time in update: 2.198033
# Elapsed time in update: 2.204323
# Elapsed time in update: 2.213365
# Elapsed time in update: 2.183215
# Elapsed time in update: 2.226448
# Elapsed time in update: 2.223363
# Elapsed time in update: 2.202698
# Elapsed time in update: 2.189904
# Elapsed time in update: 2.215016
# Iteration: 00022620/01000000
# Elapsed time in update: 2.191383
# Elapsed time in update: 2.218601
# Elapsed time in update: 2.221278
# Elapsed time in update: 2.195459
# Elapsed time in update: 2.191763
# Elapsed time in update: 2.210063
# Elapsed time in update: 2.194194
# Elapsed time in update: 2.199362
# Elapsed time in update: 2.194811
# Elapsed time in update: 2.218297
# Iteration: 00022630/01000000
# Elapsed time in update: 2.210372
# Elapsed time in update: 2.209792
# Elapsed time in update: 2.202774
# Elapsed time in update: 2.213846
# Elapsed time in update: 2.201768
# Elapsed time in update: 2.208963
# Elapsed time in update: 2.190052
# Elapsed time in update: 2.215526
# Elapsed time in update: 2.206581
# Elapsed time in update: 2.207267
# Iteration: 00022640/01000000
# Elapsed time in update: 2.196555
# Elapsed time in update: 2.226315
# Elapsed time in update: 2.188208
# Elapsed time in update: 2.206977
# Elapsed time in update: 2.212167
# Elapsed time in update: 2.213804
# Elapsed time in update: 2.197669
# Elapsed time in update: 2.192755
# Elapsed time in update: 2.208143
# Elapsed time in update: 2.202174
# Iteration: 00022650/01000000
# Elapsed time in update: 2.207208
# Elapsed time in update: 2.222042
# Elapsed time in update: 2.204695
# Elapsed time in update: 2.188727
# Elapsed time in update: 2.202235
# Elapsed time in update: 2.199446
# Elapsed time in update: 2.235302
# Elapsed time in update: 2.211131
# Elapsed time in update: 2.202280
# Elapsed time in update: 2.204376
# Iteration: 00022660/01000000
# Elapsed time in update: 2.196129
# Elapsed time in update: 2.197231
# Elapsed time in update: 2.179623
# Elapsed time in update: 2.201362
# Elapsed time in update: 2.192101
# Elapsed time in update: 2.194665
# Elapsed time in update: 2.208595
# Elapsed time in update: 2.227818
# Elapsed time in update: 2.203041
# Elapsed time in update: 2.212913
# Iteration: 00022670/01000000
# Elapsed time in update: 2.187122
# Elapsed time in update: 2.194999
# Elapsed time in update: 2.194659
# Elapsed time in update: 2.240789
# Elapsed time in update: 2.203578
# Elapsed time in update: 2.211557
# Elapsed time in update: 2.194580
# Elapsed time in update: 2.190774
# Elapsed time in update: 2.202572
# Elapsed time in update: 2.195998
# Iteration: 00022680/01000000
# Elapsed time in update: 2.210330
# Elapsed time in update: 2.200350
# Elapsed time in update: 2.195688
# Elapsed time in update: 2.202293
# Elapsed time in update: 2.215528
# Elapsed time in update: 2.198682
# Elapsed time in update: 2.209124
# Elapsed time in update: 2.207764
# Elapsed time in update: 2.225806
# Elapsed time in update: 2.211652
# Iteration: 00022690/01000000
# Elapsed time in update: 2.194270
# Elapsed time in update: 2.209931
# Elapsed time in update: 2.206063
# Elapsed time in update: 2.203563
# Elapsed time in update: 2.188019
# Elapsed time in update: 2.191036
# Elapsed time in update: 2.215840
# Elapsed time in update: 2.202977
# Elapsed time in update: 2.226990
# Elapsed time in update: 2.193834
# Iteration: 00022700/01000000
# Elapsed time in update: 2.193297
# Elapsed time in update: 2.179594
# Elapsed time in update: 2.198400
# Elapsed time in update: 2.224144
# Elapsed time in update: 2.219197
# Elapsed time in update: 2.229553
# Elapsed time in update: 2.191554
# Elapsed time in update: 2.201957
# Elapsed time in update: 2.196265
# Elapsed time in update: 2.218204
# Iteration: 00022710/01000000
# Elapsed time in update: 2.200869
# Elapsed time in update: 2.224171
# Elapsed time in update: 2.191074
# Elapsed time in update: 2.201073
# Elapsed time in update: 2.198767
# Elapsed time in update: 2.235958
# Elapsed time in update: 2.218083
# Elapsed time in update: 2.219733
# Elapsed time in update: 2.199409
# Elapsed time in update: 2.215243
# Iteration: 00022720/01000000
# Elapsed time in update: 2.222661
# Elapsed time in update: 2.201977
# Elapsed time in update: 2.204467
# Elapsed time in update: 2.215847
# Elapsed time in update: 2.229777
# Elapsed time in update: 2.199393
# Elapsed time in update: 2.203979
# Elapsed time in update: 2.194197
# Elapsed time in update: 2.203061
# Elapsed time in update: 2.198844
# Iteration: 00022730/01000000
# Elapsed time in update: 2.201208
# Elapsed time in update: 2.197605
# Elapsed time in update: 2.210528
# Elapsed time in update: 2.211111
# Elapsed time in update: 2.201746
# Elapsed time in update: 2.196008
# Elapsed time in update: 2.205225
# Elapsed time in update: 2.202183
# Elapsed time in update: 2.226902
# Elapsed time in update: 2.190380
# Iteration: 00022740/01000000
# Elapsed time in update: 2.192175
# Elapsed time in update: 2.206365
# Elapsed time in update: 2.196883
# Elapsed time in update: 2.177508
# Elapsed time in update: 2.202012
# Elapsed time in update: 2.212286
# Elapsed time in update: 2.212682
# Elapsed time in update: 2.199902
# Elapsed time in update: 2.209363
# Elapsed time in update: 2.195961
# Iteration: 00022750/01000000
# Elapsed time in update: 2.207864
# Elapsed time in update: 2.224343
# Elapsed time in update: 2.206820
# Elapsed time in update: 2.202563
# Elapsed time in update: 2.205234
# Elapsed time in update: 2.191244
# Elapsed time in update: 2.207068
# Elapsed time in update: 2.208645
# Elapsed time in update: 2.187393
# Elapsed time in update: 2.231363
# Iteration: 00022760/01000000
# Elapsed time in update: 2.199442
# Elapsed time in update: 2.195482
# Elapsed time in update: 2.205155
# Elapsed time in update: 2.203664
# Elapsed time in update: 2.210070
# Elapsed time in update: 2.206720
# Elapsed time in update: 2.182469
# Elapsed time in update: 2.231926
# Elapsed time in update: 2.207764
# Elapsed time in update: 2.211598
# Iteration: 00022770/01000000
# Elapsed time in update: 2.203435
# Elapsed time in update: 2.214520
# Elapsed time in update: 2.237477
# Elapsed time in update: 2.225662
# Elapsed time in update: 2.187657
# Elapsed time in update: 2.202211
# Elapsed time in update: 2.202753
# Elapsed time in update: 2.208311
# Elapsed time in update: 2.191654
# Elapsed time in update: 2.193452
# Iteration: 00022780/01000000
# Elapsed time in update: 2.202726
# Elapsed time in update: 2.227178
# Elapsed time in update: 2.204181
# Elapsed time in update: 2.199692
# Elapsed time in update: 2.197984
# Elapsed time in update: 2.197780
# Elapsed time in update: 2.211981
# Elapsed time in update: 2.233694
# Elapsed time in update: 2.229934
# Elapsed time in update: 2.202365
# Iteration: 00022790/01000000
# Elapsed time in update: 2.220280
# Elapsed time in update: 2.194237
# Elapsed time in update: 2.190649
# Elapsed time in update: 2.213055
# Elapsed time in update: 2.203804
# Elapsed time in update: 2.247599
# Elapsed time in update: 2.207081
# Elapsed time in update: 2.181477
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f7129b56940>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# Traceback (most recent call last):
#   File "train.py", line 59, in <module>
#     for it, (images_a, images_b) in enumerate(zip(train_loader_a, train_loader_b)):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 336, in __next__
#     return self._process_next_batch(batch)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 357, in _process_next_batch
#     raise batch.exc_type(batch.exc_msg)
# OSError: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/drive/My Drive/UNIT/data.py", line 127, in __getitem__
#     img = self.loader(path)
#   File "/drive/My Drive/UNIT/data.py", line 9, in default_loader
#     return Image.open(open(path, 'rb')).convert('RGB')
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 899, in convert
#     self.load()
#   File "/usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py", line 236, in load
#     len(b))
# OSError: image file is truncated (106 bytes not processed)
#
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f712a4052b0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 487, in Client
#     c = SocketClient(address)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 614, in SocketClient
#     s.connect(address)
# ConnectionRefusedError: [Errno 111] Connection refused
# =====================================================================
# Fully Trained!
# =====================================================================

# %%
#@title ### Results
iterations = 5004 #@param {type:"slider", min:10, max:10000, step:1}
image_size = 30 #@param {type:"slider", min:15, max:50, step:1}
iterations = int(iterations)
import os
from IPython.display import Image, display, HTML
import cv2
import matplotlib.pyplot as plt


def getTitle(name, it):
    title = ''
    if name[4] == 'a':
        title += 'Day 2 Night'
    else:
        title += 'Night 2 Day'
    if name[7:13] == '_test_':
        title += ' - Test '
    else:
        title += ' - Train '
    return title + str(it)

def displayImage(file, title):
    image = cv2.imread(file)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(image_size,image_size))
    plt.title(title);
    plt.imshow(image)
    plt.grid(False)

os.chdir('/content/drive/UNIT/outputs/unit_day2night/images/')
print(f'Selected iterations: {iterations}')
for r, d, f in os.walk('./'):
    file = f[0]
    num_pit = int(file[-12:-4])
    title = getTitle(file, num_pit)
    displayImage(file, title)
    for file in f[1:]:
        if file[-12:-4] != '_current':
            num_it  = int(file[-12:-4])
            if num_it - num_pit >= iterations or num_it == num_pit:
                title = getTitle(file, num_it)
                displayImage(file, title)
                num_pit = num_it

# %% [markdown]
# ### Summer-2-Winter Translation

# %%
#@title ### Training Winter 2 Summer
Resume_from_last_checkpoint = True #@param {type:"boolean"}
Checkpoint_every_iteration = 1000 #@param {type:"slider", min:100, max:5000, step:100}



if Resume_from_last_checkpoint:
    rsm = '--resume'
else:
    rsm = ''

import os
if not os.path.isdir('/content/drive'):
    print('=====================================================================')
    print('Session ended! Please remount google.drive and reinstall dependences!')
    print('=====================================================================')
else:
    os.chdir('/content/drive/UNIT')

    print('=====================================================================')
    print('Training a model Summer to Winter image translation')
    print('=====================================================================')
    # !python train.py --config configs/unit_summer2winter_yosemite256_folder.yaml --trainer UNIT $rsm
    print('=====================================================================')
    print('Fully Trained!')
    print('=====================================================================')

# %%
#@title ### Results
iterations = 5004 #@param {type:"slider", min:10, max:10000, step:1}
image_size = 30 #@param {type:"slider", min:15, max:50, step:1}
iterations = int(iterations)
import os
from IPython.display import Image, display, HTML
import cv2
import matplotlib.pyplot as plt


def getTitle(name, it):
    title = ''
    if name[4] == 'a':
        title += 'Summer 2 Winter'
    else:
        title += 'Winter 2 Summer'
    if name[7:13] == '_test_':
        title += ' - Test '
    else:
        title += ' - Train '
    return title + str(it)

def displayImage(file, title):
    image = cv2.imread(file)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(image_size,image_size))
    plt.title(title);
    plt.imshow(image)
    plt.grid(False)

os.chdir('/content/drive/UNIT/outputs/unit_summer2winter_yosemite256_folder/images/')
# print(os.getcwd())
print(f'Selected iterations: {iterations}')
for r, d, f in os.walk('./'):
    file = f[0]
    num_pit = int(file[-12:-4])
    title = getTitle(file, num_pit)
    displayImage(file, title)
    for file in f[1:]:
        if file[-12:-4] != '_current':
            num_it  = int(file[-12:-4])
            if num_it - num_pit >= iterations or num_it == num_pit:
                title = getTitle(file, num_it)
                displayImage(file, title)
                num_pit = num_it

# %% [markdown]
# <!-- ![]()
#  ![Google's logo](/content/drive/UNIT/outputs/unit_summer2winter_yosemite256_folder/images/gen_a2b_test_00000010.png) -->

# %% [markdown]
# ## Test

# %%
#@title ### Testing on PT models
#TODO: add day2night
from IPython.display import Image, display
import os

Model = "gta2city" #@param ['gta2city', 'day2night', 'summer2winter']
backward = False #@param {type:"boolean"}


if not os.path.isdir('/content/drive'):
    print('=====================================================================')
    print('Session ended! Please remount google.drive and reinstall dependences!')
    print('=====================================================================')
    assert(False)
    
os.chdir('/content/drive/UNIT')


if not backward:
    print('=====================================================================')
    print('Testing: gta2city')
    print('=====================================================================')


    ! python test.py --trainer UNIT --config configs/unit_gta2city_list.yaml --input inputs/gta3.jpg --output_folder results/gta2city --checkpoint models/unit_gta2city.pt --a2b 1

    print('=====================================================================')
    print('Input')
    display(Image('/content/drive/UNIT/results/gta2city/input.jpg', width=800))
    print('Output')
    display(Image('/content/drive/UNIT/results/gta2city/output.jpg', width=800))

if backward:
    print('=====================================================================')
    print('Testing: city2gta')
    print('=====================================================================')
   
    ! python test.py --trainer UNIT --config configs/unit_gta2city_list.yaml --input inputs/city_example.jpg --output_folder results/city2gta --checkpoint models/unit_gta2city.pt --a2b 0

    print('=====================================================================')
    print('Input')
    display(Image('/content/drive/UNIT/results/city2gta/input.jpg', width=800))
    print('Output')
    display(Image('/content/drive/UNIT/results/city2gta/output.jpg', width=800))
